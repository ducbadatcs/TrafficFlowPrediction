# %%
import pandas as pd 
from glob import glob 
# read files

file_list = []

for file in glob("./datasets/VicRoads/*.csv"):
    print(file)
    file_list.append(file)
    
df = pd.concat([pd.read_csv(file) for file in glob("./datasets/VicRoads/*.csv")])
# Out:
# ./datasets/VicRoads\VSDATA_20251001.csv
# ./datasets/VicRoads\VSDATA_20251002.csv
# ./datasets/VicRoads\VSDATA_20251003.csv
# ./datasets/VicRoads\VSDATA_20251004.csv
# ./datasets/VicRoads\VSDATA_20251005.csv

# %%
df.head(10)
# Out:
#    NB_SCATS_SITE QT_INTERVAL_COUNT  NB_DETECTOR  V00  V01  V02  V03  V04  V05  \
# 0            100        2025-10-01            1    2    2    3    2    1    2
# 1            100        2025-10-01            2   12   17    6    7    5    9
# 2            100        2025-10-01            3   25   22   15   13   14   13
# 3            100        2025-10-01            4    8   13    2    6    9    7
# 4            100        2025-10-01            5    1    0    4    1    0    0
# 5            100        2025-10-01            6    0    0    0    0    0    0
# 6            100        2025-10-01            7    0    0    0    0    0    0
# 7            100        2025-10-01            8    0    0    0    0    0    0
# 8            100        2025-10-01            9    0    0    0    0    0    0
# 9            100        2025-10-01           10    0    0    0    0    0    0
#
#    V06  ...  V90  V91  V92  V93  V94  V95  NM_REGION  CT_RECORDS  \
# ...

# %%
pd.Categorical(df["NB_SCATS_SITE"])
# Out:
# [100, 100, 100, 100, 100, ..., 42118, 42118, 42118, 42118, 42118]
# Length: 582847
# Categories (4682, int64): [100, 101, 102, 103, ..., 32249, 32268, 32400, 42118]

# %%
|
